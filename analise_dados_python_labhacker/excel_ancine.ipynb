# %%
# https://www.youtube.com/watch?v=2oZHg3HOtcY&t=1s

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Fonte: https://oca.ancine.gov.br/sites/default/files/repositorio/excel/2120_0.xlsx

# %%
df = pd.read_excel('ancine/2120_0.xlsx',sheet_name='2120', skiprows=2)

# %%
df.reset_index().head()
# Out:
#    index Ano de exibição                      Título da obra        Gênero  \
# 0      0            2017                          #Screamers        Ficção
# 1      1            2017  10 Centavos para o Número da Besta  Documentário
# 2      2            2017           120 batimentos por minuto        Ficção
# 3      3            2017                          13 Minutos        Ficção
# 4      4            2017                      150 Miligramas        Ficção
#
#   País(es) produtor(es) da obra Nacionalidade da obra   Data de lançamento  \
# 0                Estados Unidos          Estrangeiros  2017-11-30 00:00:00
# 1                        Brasil           Brasileiros  2017-11-28 00:00:00
# 2                        França          Estrangeiros  2018-01-04 00:00:00
# 3                      Alemanha          Estrangeiros  2016-11-03 00:00:00
# 4                        França          Estrangeiros  2017-08-31 00:00:00
#
#          Distribuidora Origem da empresa distribuidora  \
# 0       Cineart Filmes           Distribuição Nacional
# 1  Ponto de Equilíbrio           Distribuição Nacional
# 2           Imovision            Distribuição Nacional
# 3    Alphaville Filmes           Distribuição Nacional
# 4          Califórnia            Distribuição Nacional
#
#    Público no ano de exibição  Renda (R$) no ano de exibição
# 0                       714.0                        9437.45
# 1                         7.0                          63.00
# 2                       262.0                        3791.63
# 3                       620.0                        6463.50
# 4                       771.0                       10508.71

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5707 entries, 0 to 5706
# Data columns (total 10 columns):
# Ano de exibição                    5704 non-null object
# Título da obra                     5691 non-null object
# Gênero                             5691 non-null object
# País(es) produtor(es) da obra      5691 non-null object
# Nacionalidade da obra              5691 non-null object
# Data de lançamento                 5691 non-null object
# Distribuidora                      5691 non-null object
# Origem da empresa distribuidora    5691 non-null object
# Público no ano de exibição         5691 non-null float64
# Renda (R$) no ano de exibição      5691 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 445.9+ KB

# %%
df.reset_index().tail(20)
# Out:
#       index                                    Ano de exibição  \
# 5687   5687                                               2009
# 5688   5688                                               2009
# 5689   5689                                               2009
# 5690   5690                                               2009
# 5691   5691                                                NaN
# 5692   5692                                             Notas:
# 5693   5693  1. Esse arquivo disponibiliza os filmes exibid...
# 5694   5694  2. Um filme pode ter mais de uma empresa distr...
# 5695   5695  3. Para um melhor alinhamento com o mercado in...
# 5696   5696  4. Para um filme ser considerado brasileiro, o...
# 5697   5697  5. Os valores de renda disponíveis nesse arqui...
# 5698   5698  6. ND: Dados não infomados pela distribuidora ...
# 5699   5699  7. O ano de exibição corresponde aos seguintes...
# 5700   5700  8. Foram consideradas distribuidoras internaci...
# 5701   5701                                                NaN
# 5702   5702                                             Fonte:
# 5703   5703  2016 e 2017: ANCINE / SADIS (Sistema de Acompa...
# 5704   5704  2009 a 2015: ANCINE / SADIS (Sistema de Acompa...
# 5705   5705                                                NaN
# 5706   5706  Elaboração: Coordenação do Observatório do Cin...
#
#                        Título da obra        Gênero  \
# 5687  Xuxa em o Mistério de Feiurinha        Ficção
# 5688          Xuxa em Sonho de Menina        Ficção
# 5689                      Xuxa Gêmeas        Ficção
# 5690                     Zico na Rede  Documentário
# 5691                              NaN           NaN
# 5692                              NaN           NaN
# 5693                              NaN           NaN
# 5694                              NaN           NaN
# 5695                              NaN           NaN
# 5696                              NaN           NaN
# 5697                              NaN           NaN
# 5698                              NaN           NaN
# 5699                              NaN           NaN
# 5700                              NaN           NaN
# 5701                              NaN           NaN
# 5702                              NaN           NaN
# 5703                              NaN           NaN
# 5704                              NaN           NaN
# 5705                              NaN           NaN
# 5706                              NaN           NaN
#
#      País(es) produtor(es) da obra Nacionalidade da obra   Data de lançamento  \
# 5687                        Brasil           Brasileiros  2009-12-25 00:00:00
# 5688                        Brasil           Brasileiros  2007-12-21 00:00:00
# 5689                        Brasil           Brasileiros  2006-12-15 00:00:00
# 5690                        Brasil           Brasileiros  2009-07-03 00:00:00
# 5691                           NaN                   NaN                  NaN
# 5692                           NaN                   NaN                  NaN
# 5693                           NaN                   NaN                  NaN
# 5694                           NaN                   NaN                  NaN
# 5695                           NaN                   NaN                  NaN
# 5696                           NaN                   NaN                  NaN
# 5697                           NaN                   NaN                  NaN
# 5698                           NaN                   NaN                  NaN
# 5699                           NaN                   NaN                  NaN
# 5700                           NaN                   NaN                  NaN
# 5701                           NaN                   NaN                  NaN
# 5702                           NaN                   NaN                  NaN
# 5703                           NaN                   NaN                  NaN
# 5704                           NaN                   NaN                  NaN
# 5705                           NaN                   NaN                  NaN
# 5706                           NaN                   NaN                  NaN
#
#          Distribuidora Origem da empresa distribuidora  \
# 5687          Playarte           Distribuição Nacional
# 5688            Warner      Distribuição Internacional
# 5689               Fox      Distribuição Internacional
# 5690  Business Telecom           Distribuição Nacional
# 5691               NaN                             NaN
# 5692               NaN                             NaN
# 5693               NaN                             NaN
# 5694               NaN                             NaN
# 5695               NaN                             NaN
# 5696               NaN                             NaN
# 5697               NaN                             NaN
# 5698               NaN                             NaN
# 5699               NaN                             NaN
# 5700               NaN                             NaN
# 5701               NaN                             NaN
# 5702               NaN                             NaN
# 5703               NaN                             NaN
# 5704               NaN                             NaN
# 5705               NaN                             NaN
# 5706               NaN                             NaN
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 5687                    250109.0                     1766416.65
# 5688                      8914.0                       26880.00
# 5689                      1671.0                        5013.00
# 5690                       546.0                        2529.50
# 5691                         NaN                            NaN
# 5692                         NaN                            NaN
# 5693                         NaN                            NaN
# 5694                         NaN                            NaN
# 5695                         NaN                            NaN
# 5696                         NaN                            NaN
# 5697                         NaN                            NaN
# 5698                         NaN                            NaN
# 5699                         NaN                            NaN
# 5700                         NaN                            NaN
# 5701                         NaN                            NaN
# 5702                         NaN                            NaN
# 5703                         NaN                            NaN
# 5704                         NaN                            NaN
# 5705                         NaN                            NaN
# 5706                         NaN                            NaN

# %%
df = pd.read_excel('ancine/2120_0.xlsx',sheet_name='2120', skiprows=2, skipfooter=16)

# %%
df.reset_index().tail(20)
# Out:
#       index  Ano de exibição                       Título da obra  \
# 5671   5671             2009               Verônika Decide Morrer
# 5672   5672             2009  Viagem ao Centro da Terra - O Filme
# 5673   5673             2009             Vicky Cristina Barcelona
# 5674   5674             2009                           Vigaristas
# 5675   5675             2009                              Vila 21
# 5676   5676             2009                   Violência Gratuita
# 5677   5677             2009                                Vitus
# 5678   5678             2009                             Viva Voz
# 5679   5679             2009                    Você é tão Bonito
# 5680   5680             2009                      Vocês, os Vivos
# 5681   5681             2009                               Volver
# 5682   5682             2009                                   W.
# 5683   5683             2009       Waldick, Sempre no meu Coração
# 5684   5684             2009                               Wall-E
# 5685   5685             2009                   Watchmen - O Filme
# 5686   5686             2009             X-Men Origens: Wolverine
# 5687   5687             2009      Xuxa em o Mistério de Feiurinha
# 5688   5688             2009              Xuxa em Sonho de Menina
# 5689   5689             2009                          Xuxa Gêmeas
# 5690   5690             2009                         Zico na Rede
#
#             Gênero País(es) produtor(es) da obra Nacionalidade da obra  \
# 5671        Ficção                Estados Unidos          Estrangeiros
# 5672        Ficção                Estados Unidos          Estrangeiros
# 5673        Ficção                Estados Unidos          Estrangeiros
# 5674        Ficção                Estados Unidos          Estrangeiros
# 5675        Ficção                     Argentina          Estrangeiros
# 5676        Ficção                Estados Unidos          Estrangeiros
# 5677        Ficção                         Suíça          Estrangeiros
# 5678        Ficção                        Brasil           Brasileiros
# 5679        Ficção                        França          Estrangeiros
# 5680        Ficção                        Suécia          Estrangeiros
# 5681        Ficção                       Espanha          Estrangeiros
# 5682        Ficção                Estados Unidos          Estrangeiros
# 5683  Documentário                        Brasil           Brasileiros
# 5684      Animação                Estados Unidos          Estrangeiros
# 5685        Ficção                Estados Unidos          Estrangeiros
# 5686        Ficção                Estados Unidos          Estrangeiros
# 5687        Ficção                        Brasil           Brasileiros
# 5688        Ficção                        Brasil           Brasileiros
# 5689        Ficção                        Brasil           Brasileiros
# 5690  Documentário                        Brasil           Brasileiros
#
#        Data de lançamento      Distribuidora Origem da empresa distribuidora  \
# 5671  2009-08-21 00:00:00            Imagem            Distribuição Nacional
# 5672  2008-07-11 00:00:00           Playarte           Distribuição Nacional
# 5673  2008-11-14 00:00:00            Imagem            Distribuição Nacional
# 5674  2009-10-23 00:00:00             Paris            Distribuição Nacional
# 5675  2009-09-25 00:00:00       Panda Filmes           Distribuição Nacional
# 5676  2008-09-19 00:00:00        Califórnia            Distribuição Nacional
# 5677  2009-03-06 00:00:00   Filmes da Mostra           Distribuição Nacional
# 5678  2004-05-21 00:00:00              Sony       Distribuição Internacional
# 5679  2006-12-22 00:00:00           Pandora            Distribuição Nacional
# 5680  2009-04-11 00:00:00   Filmes da Mostra           Distribuição Nacional
# 5681  2006-11-10 00:00:00                Fox      Distribuição Internacional
# 5682  2009-04-10 00:00:00  Filmes do Estação           Distribuição Nacional
# 5683  2009-08-21 00:00:00    Pequena Central           Distribuição Nacional
# 5684  2008-06-27 00:00:00              Sony       Distribuição Internacional
# 5685  2009-03-06 00:00:00          Paramount      Distribuição Internacional
# 5686  2009-05-01 00:00:00                Fox      Distribuição Internacional
# 5687  2009-12-25 00:00:00           Playarte           Distribuição Nacional
# 5688  2007-12-21 00:00:00             Warner      Distribuição Internacional
# 5689  2006-12-15 00:00:00                Fox      Distribuição Internacional
# 5690  2009-07-03 00:00:00   Business Telecom           Distribuição Nacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 5671                       41562                      361321.23
# 5672                        2037                       18359.50
# 5673                       84725                      731922.60
# 5674                       35314                      330030.97
# 5675                         299                        2428.00
# 5676                         269                        1439.60
# 5677                        5465                       43348.80
# 5678                         429                        1287.00
# 5679                         846                        4179.50
# 5680                        6885                       58619.52
# 5681                         282                        1742.00
# 5682                       12741                      120724.60
# 5683                        3591                       17076.50
# 5684                         286                        1016.00
# 5685                      539796                     4630370.00
# 5686                     3199434                    27352313.00
# 5687                      250109                     1766416.65
# 5688                        8914                       26880.00
# 5689                        1671                        5013.00
# 5690                         546                        2529.50

# %%
df.dtypes
# Out:
# Ano de exibição                      int64
# Título da obra                      object
# Gênero                              object
# País(es) produtor(es) da obra       object
# Nacionalidade da obra               object
# Data de lançamento                  object
# Distribuidora                       object
# Origem da empresa distribuidora     object
# Público no ano de exibição           int64
# Renda (R$) no ano de exibição      float64
# dtype: object

# %%
# Converte campo em data

# %%
df['Data de lançamento'] = pd.to_datetime(df['Data de lançamento'])
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime._string_to_dts()
#
# UnicodeEncodeError: 'ascii' codec can't encode character '\xe7' in position 5: ordinal not in range(128)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/Documentos/Code/LabHacker/lib/python3.6/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1355     else:
# -> 1356         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1357
#
# ~/Documentos/Code/LabHacker/lib/python3.6/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647         if res is None:
# --> 648             raise ValueError("Unknown string format:", timestr)
#     649
#
# ValueError: ('Unknown string format:', 'Relançamento')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-3f6a02fcf961> in <module>
# ----> 1 df['Data de lançamento'] = pd.to_datetime(df['Data de lançamento'])
#
# ~/Documentos/Code/LabHacker/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     449         else:
#     450             from pandas import Series
# --> 451             values = _convert_listlike(arg._values, True, format)
#     452             result = Series(values, index=arg.index, name=arg.name)
#     453     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# ~/Documentos/Code/LabHacker/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     366                     dayfirst=dayfirst,
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#     370
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime

# %%
# Identifica problema da coluna

# %%
df['Data de lançamento'].value_counts()
# Out:
# Relançamento           175
# 2012-12-21 00:00:00     33
# 2015-12-03 00:00:00     33
# 2013-11-29 00:00:00     29
# 2012-11-02 00:00:00     27
# 2015-11-19 00:00:00     25
# 2015-11-12 00:00:00     25
# 2013-12-06 00:00:00     23
# 2013-10-11 00:00:00     23
# 2013-11-01 00:00:00     23
# 2016-11-17 00:00:00     23
# 2011-11-11 00:00:00     21
# 2011-12-02 00:00:00     21
# 2014-11-06 00:00:00     21
# 2013-09-13 00:00:00     21
# 2009-12-11 00:00:00     20
# 2011-12-09 00:00:00     19
# 2013-12-20 00:00:00     19
# 2011-09-30 00:00:00     19
# 2014-06-19 00:00:00     19
# 2016-11-10 00:00:00     19
# 2015-08-20 00:00:00     18
# 2011-11-25 00:00:00     18
# 2015-11-26 00:00:00     18
# 2016-12-01 00:00:00     18
# 2015-12-10 00:00:00     18
# 2013-09-06 00:00:00     18
# 2016-11-24 00:00:00     18
# 2012-10-12 00:00:00     18
# 2014-12-04 00:00:00     18
#                       ...
# 2005-01-14 00:00:00      1
# 2014-06-28 00:00:00      1
# 2006-01-20 00:00:00      1
# 2004-11-06 00:00:00      1
# 2018-03-15 00:00:00      1
# 2004-01-09 00:00:00      1
# 2017-12-25 00:00:00      1
# 2010-09-04 00:00:00      1
# 2007-05-25 00:00:00      1
# 2007-04-06 00:00:00      1
# 2002-01-01 00:00:00      1
# 2006-09-22 00:00:00      1
# 2016-07-25 00:00:00      1
# 2008-05-02 00:00:00      1
# 2015-07-03 00:00:00      1
# 2018-11-29 00:00:00      1
# 2014-11-24 00:00:00      1
# 2011-06-04 00:00:00      1
# 2007-06-30 00:00:00      1
# 2007-09-21 00:00:00      1
# 2018-02-22 00:00:00      1
# 2015-09-29 00:00:00      1
# 2009-10-28 00:00:00      1
# 2011-08-13 00:00:00      1
# 2006-08-25 00:00:00      1
# 2015-06-07 00:00:00      1
# 2011-02-05 00:00:00      1
# 2004-05-21 00:00:00      1
# 2002-07-19 00:00:00      1
# 2017-11-28 00:00:00      1
# Name: Data de lançamento, Length: 759, dtype: int64

# %%
df[df['Data de lançamento'] == 'Relançamento'].head()
# Out:
#      Ano de exibição                     Título da obra        Gênero  \
# 7               2017                                 8½        Ficção
# 11              2017                    A bela da tarde        Ficção
# 36              2017                 A História sem Fim        Ficção
# 53              2017       A primeira noite de um homem        Ficção
# 128             2017  Ballet Bolshoi: A bela adormecida  Vídeomusical
#
#     País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 7                  França, Itália          Estrangeiros       Relançamento
# 11                 França, Itália          Estrangeiros       Relançamento
# 36       Alemanha, Estados Unidos          Estrangeiros       Relançamento
# 53                 Estados Unidos          Estrangeiros       Relançamento
# 128                    Inglaterra          Estrangeiros       Relançamento
#
#     Distribuidora Origem da empresa distribuidora  Público no ano de exibição  \
# 7     F. J. Cines           Distribuição Nacional                          29
# 11    Zeta Filmes           Distribuição Nacional                        3011
# 36    F. J. Cines           Distribuição Nacional                         797
# 53    Zeta Filmes           Distribuição Nacional                          12
# 128           UCI           Distribuição Nacional                        1504
#
#      Renda (R$) no ano de exibição
# 7                           196.00
# 11                        42839.31
# 36                         6969.00
# 53                           96.00
# 128                       41391.00

# %%
# Decisão para descartar os dados Relançamento

# %%
df.shape
# Out:
# (5691, 10)

# %%
df_novo = df[df['Data de lançamento'] != 'Relançamento'].copy()

# %%
df_novo['Data de lançamento'] = pd.to_datetime(df_novo['Data de lançamento'])

# %%
df_novo.dtypes
# Out:
# Ano de exibição                             int64
# Título da obra                             object
# Gênero                                     object
# País(es) produtor(es) da obra              object
# Nacionalidade da obra                      object
# Data de lançamento                 datetime64[ns]
# Distribuidora                              object
# Origem da empresa distribuidora            object
# Público no ano de exibição                  int64
# Renda (R$) no ano de exibição             float64
# dtype: object

# %%
# Conta por ano

# %%
df_novo['Data de lançamento'].dt.year.value_counts()
# Out:
# 2013    669
# 2015    646
# 2014    619
# 2016    613
# 2011    553
# 2012    539
# 2009    503
# 2017    487
# 2010    475
# 2008    225
# 2007     61
# 2006     49
# 2005     29
# 2018     17
# 2004     10
# 2002      6
# 2001      5
# 2003      4
# 1999      3
# 2000      2
# 1998      1
# Name: Data de lançamento, dtype: int64

# %%
df_novo['Data de lançamento'].dt.year.value_counts().plot.bar()

# %%
# Maior bilheteria

# %%
df_novo[df_novo['Renda (R$) no ano de exibição'] == df_novo['Renda (R$) no ano de exibição'].max()]
# Out:
#       Ano de exibição               Título da obra  Gênero  \
# 2249             2015  Vingadores: A Era de Ultron  Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 2249                Estados Unidos          Estrangeiros         2015-04-23
#
#      Distribuidora Origem da empresa distribuidora  \
# 2249        Disney      Distribuição Internacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 2249                    10129071                    146184931.0

# %%
df_novo.nlargest(3, 'Renda (R$) no ano de exibição')
# Out:
#       Ano de exibição                 Título da obra  Gênero  \
# 2249             2015    Vingadores: A Era de Ultron  Ficção
# 893              2016  Capitão América: Guerra civil  Ficção
# 2242             2015           Velozes e Furiosos 7  Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 2249                Estados Unidos          Estrangeiros         2015-04-23
# 893                 Estados Unidos          Estrangeiros         2016-04-28
# 2242                Estados Unidos          Estrangeiros         2015-04-02
#
#      Distribuidora Origem da empresa distribuidora  \
# 2249        Disney      Distribuição Internacional
# 893         Disney      Distribuição Internacional
# 2242     Universal      Distribuição Internacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 2249                    10129071                   1.461849e+08
# 893                      9617572                   1.433370e+08
# 2242                     9857946                   1.424659e+08

# %%
df_novo.nsmallest(3, 'Renda (R$) no ano de exibição')
# Out:
#       Ano de exibição            Título da obra        Gênero  \
# 2277             2014     A Batalha do passinho  Documentário
# 2608             2014                 Mar negro        Ficção
# 2728             2014  O Último Lance do Leilão        Ficção
#
#      País(es) produtor(es) da obra Nacionalidade da obra Data de lançamento  \
# 2277                        Brasil           Brasileiros         2013-10-11
# 2608                        Brasil           Brasileiros         2014-01-17
# 2728                        Brasil           Brasileiros         2014-05-01
#
#            Distribuidora Origem da empresa distribuidora  \
# 2277   Cine Santa Teresa           Distribuição Nacional
# 2608             Petrini           Distribuição Nacional
# 2728  Sam Rádio Pictures           Distribuição Nacional
#
#       Público no ano de exibição  Renda (R$) no ano de exibição
# 2277                         355                            0.0
# 2608                           0                            0.0
# 2728                           0                            0.0

# %%
df_novo[df_novo['Renda (R$) no ano de exibição'] == df_novo['Renda (R$) no ano de exibição'].min()]
# Out:
#       Ano de exibição                                     Título da obra  \
# 2277             2014                              A Batalha do passinho
# 2608             2014                                          Mar negro
# 2728             2014                           O Último Lance do Leilão
# 3041             2013                                  As horas vulgares
# 3058             2013                                 Beije-me outra vez
# 3105             2013                                        Crazy Horse
# 3390             2013                                     Quase um tango
# 3459             2013                                      Todos os Dias
# 3603             2012                                   Apenas entre Nós
# 3627             2012                                   Ataque ao prédio
# 3665             2012                 Clementina de Jesus - Rainha Quelé
# 3787             2012                                       Luto em Luta
# 3815             2012                                Movimento Browniano
# 3829             2012                                           O abrigo
# 3920             2012                                          Ponto Org
# 4085             2011                          A Última Estrada da Praia
# 4462             2011                                  Poema de Salvação
# 4466             2011          Porta a porta – A política em dois tempos
# 4587             2011                                           Walachai
# 4732             2010              Cine Cocoricó: As Aventuras na Cidade
# 4853             2010                                      Luto Como Mãe
# 5022             2010              Simonal - Ninguém Sabe o Duro que Dei
# 5203             2009                                  As Chaves de Casa
# 5463             2009  Naufrágio - Mistério e Morte na Catástrofe do ...
# 5591             2009                                           Santiago
# 5666             2009                                  Vamos Subir, Leão
#
#             Gênero       País(es) produtor(es) da obra Nacionalidade da obra  \
# 2277  Documentário                              Brasil           Brasileiros
# 2608        Ficção                              Brasil           Brasileiros
# 2728        Ficção                              Brasil           Brasileiros
# 3041        Ficção                              Brasil           Brasileiros
# 3058        Ficção                              Itália          Estrangeiros
# 3105        Ficção                      Estados Unidos          Estrangeiros
# 3390        Ficção                              Brasil           Brasileiros
# 3459        Ficção                         Reino Unido          Estrangeiros
# 3603        Ficção  França, Eslovênia, Sérvia, Croácia          Estrangeiros
# 3627        Ficção                         Reino Unido          Estrangeiros
# 3665  Documentário                              Brasil           Brasileiros
# 3787  Documentário                              Brasil           Brasileiros
# 3815        Ficção                             Holanda          Estrangeiros
# 3829        Ficção                      Estados Unidos          Estrangeiros
# 3920        Ficção                              Brasil           Brasileiros
# 4085        Ficção                              Brasil           Brasileiros
# 4462        Ficção                           Argentina          Estrangeiros
# 4466  Documentário                              Brasil           Brasileiros
# 4587  Documentário                              Brasil           Brasileiros
# 4732        Ficção                              Brasil           Brasileiros
# 4853  Documentário                              Brasil           Brasileiros
# 5022  Documentário                              Brasil           Brasileiros
# 5203        Ficção                              Itália          Estrangeiros
# 5463  Documentário                              Brasil           Brasileiros
# 5591  Documentário                              Brasil           Brasileiros
# 5666  Documentário                              Brasil           Brasileiros
#
#      Data de lançamento                  Distribuidora  \
# 2277         2013-10-11              Cine Santa Teresa
# 2608         2014-01-17                        Petrini
# 2728         2014-05-01             Sam Rádio Pictures
# 3041         2013-08-09                        Petrini
# 3058         2013-05-10                        Petrini
# 3105         2013-06-28                        Petrini
# 3390         2013-08-16                  NGM Produções
# 3459         2014-01-24               Esfera Produções
# 3603         2015-05-07                           Lume
# 3627         2012-01-13                          Sony
# 3665         2012-11-15  Werinton Kermes Telles Marsal
# 3787         2012-09-21                    Like Filmes
# 3815         2012-07-06                        Petrini
# 3829         2012-06-01                          Sony
# 3920         2012-09-21                  Usina Digital
# 4085         2011-09-16                 Okna Produções
# 4462         2011-09-30                 Canzión filmes
# 4466         2011-12-02               Zéfiro Produções
# 4587         2011-11-18                      Ciclorama
# 4732         2009-07-17                     Moviemobz
# 4853         2010-08-20                 TV Zero Cinema
# 5022         2009-05-15             Moviemobz/RioFilme
# 5203         2006-01-06              Filmes do Estação
# 5463         2009-12-25          Master Shot Produções
# 5591         2007-08-24                    Videofilmes
# 5666         2009-03-20                        Canal 3
#
#      Origem da empresa distribuidora  Público no ano de exibição  \
# 2277           Distribuição Nacional                         355
# 2608           Distribuição Nacional                           0
# 2728           Distribuição Nacional                           0
# 3041           Distribuição Nacional                           0
# 3058           Distribuição Nacional                           0
# 3105           Distribuição Nacional                           0
# 3390           Distribuição Nacional                           0
# 3459           Distribuição Nacional                           0
# 3603           Distribuição Nacional                           0
# 3627      Distribuição Internacional                           0
# 3665           Distribuição Nacional                           0
# 3787           Distribuição Nacional                           0
# 3815           Distribuição Nacional                           0
# 3829      Distribuição Internacional                           0
# 3920           Distribuição Nacional                           0
# 4085           Distribuição Nacional                           0
# 4462           Distribuição Nacional                           0
# 4466           Distribuição Nacional                           0
# 4587           Distribuição Nacional                           0
# 4732           Distribuição Nacional                           1
# 4853           Distribuição Nacional                           0
# 5022           Distribuição Nacional                           1
# 5203           Distribuição Nacional                           0
# 5463           Distribuição Nacional                           0
# 5591           Distribuição Nacional                           0
# 5666           Distribuição Nacional                           0
#
#       Renda (R$) no ano de exibição
# 2277                            0.0
# 2608                            0.0
# 2728                            0.0
# 3041                            0.0
# 3058                            0.0
# 3105                            0.0
# 3390                            0.0
# 3459                            0.0
# 3603                            0.0
# 3627                            0.0
# 3665                            0.0
# 3787                            0.0
# 3815                            0.0
# 3829                            0.0
# 3920                            0.0
# 4085                            0.0
# 4462                            0.0
# 4466                            0.0
# 4587                            0.0
# 4732                            0.0
# 4853                            0.0
# 5022                            0.0
# 5203                            0.0
# 5463                            0.0
# 5591                            0.0
# 5666                            0.0

# %%
df_novo['Nacionalidade da obra'].value_counts()
# Out:
# Estrangeiros    3902
# Brasileiros     1614
# Name: Nacionalidade da obra, dtype: int64

# %%
df_novo.count?
# Out:
# Signature: df_novo.count(axis=0, level=None, numeric_only=False)
# Docstring:
# Count non-NA cells for each column or row.
#
# The values `None`, `NaN`, `NaT`, and optionally `numpy.inf` (depending
# on `pandas.options.mode.use_inf_as_na`) are considered NA.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     If 0 or 'index' counts are generated for each column.
#     If 1 or 'columns' counts are generated for each **row**.
# level : int or str, optional
#     If the axis is a `MultiIndex` (hierarchical), count along a
#     particular `level`, collapsing into a `DataFrame`.
#     A `str` specifies the level name.
# numeric_only : boolean, default False
#     Include only `float`, `int` or `boolean` data.
#
# Returns
# -------
# Series or DataFrame
#     For each column/row the number of non-NA/null entries.
#     If `level` is specified returns a `DataFrame`.
#
# See Also
# --------
# Series.count: number of non-NA elements in a Series
# DataFrame.shape: number of DataFrame rows and columns (including NA
#     elements)
# DataFrame.isna: boolean same-sized DataFrame showing places of NA
#     elements
#
# Examples
# --------
# Constructing DataFrame from a dictionary:
#
# >>> df = pd.DataFrame({"Person":
# ...                    ["John", "Myla", None, "John", "Myla"],
# ...                    "Age": [24., np.nan, 21., 33, 26],
# ...                    "Single": [False, True, True, True, False]})
# >>> df
#    Person   Age  Single
# 0    John  24.0   False
# 1    Myla   NaN    True
# 2    None  21.0    True
# 3    John  33.0    True
# 4    Myla  26.0   False
#
# Notice the uncounted NA values:
#
# >>> df.count()
# Person    4
# Age       4
# Single    5
# dtype: int64
#
# Counts for each **row**:
#
# >>> df.count(axis='columns')
# 0    3
# 1    2
# 2    2
# 3    3
# 4    3
# dtype: int64
#
# Counts for one level of a `MultiIndex`:
#
# >>> df.set_index(["Person", "Single"]).count(level="Person")
#         Age
# Person
# John      2
# Myla      1
# File:      ~/Documentos/Code/LabHacker/lib/python3.6/site-packages/pandas/core/frame.py
# Type:      method
